# %%
pip install langchain-tavily
# Out:
# Running cells with '.venv (Python 3.11.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/administrator/system/subsystem_01/builder/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
tools = TavilySearch()

# %%
llm = get_chat_model()
llm_with_web = llm.bind_tools(tools)
llm_with_web.invoke("How is the work culture at google?")
